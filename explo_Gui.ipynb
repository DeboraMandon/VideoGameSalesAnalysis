# %%
print('test')
print('youpi')
# Out:
# test
# youpi

# %%
# IMPORT DES MODULES ET DU DATASET 

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

path="https://raw.githubusercontent.com/DeboraMandon/video_game_sales_analysis/main/vgsales.csv"
df=pd.read_csv(path, index_col=0)
df.head(20)
# Out:
#                                               Name Platform    Year  \
# Rank
# 1                                       Wii Sports      Wii  2006.0
# 2                                Super Mario Bros.      NES  1985.0
# 3                                   Mario Kart Wii      Wii  2008.0
# 4                                Wii Sports Resort      Wii  2009.0
# 5                         Pokemon Red/Pokemon Blue       GB  1996.0
# 6                                           Tetris       GB  1989.0
# 7                            New Super Mario Bros.       DS  2006.0
# 8                                         Wii Play      Wii  2006.0
# 9                        New Super Mario Bros. Wii      Wii  2009.0
# 10                                       Duck Hunt      NES  1984.0
# 11                                      Nintendogs       DS  2005.0
# 12                                   Mario Kart DS       DS  2005.0
# 13                     Pokemon Gold/Pokemon Silver       GB  1999.0
# ...

# %%
# AFFICHAGE DU TYPE DES COLONNES DU DATASET
df[df['Genre']=='Shooter'].head(10)
# Out:
#                                 Name Platform    Year    Genre  \
# Rank
# 10                         Duck Hunt      NES  1984.0  Shooter
# 30    Call of Duty: Modern Warfare 3     X360  2011.0  Shooter
# 32           Call of Duty: Black Ops     X360  2010.0  Shooter
# 34         Call of Duty: Black Ops 3      PS4  2015.0  Shooter
# 35        Call of Duty: Black Ops II      PS3  2012.0  Shooter
# 36        Call of Duty: Black Ops II     X360  2012.0  Shooter
# 37    Call of Duty: Modern Warfare 2     X360  2009.0  Shooter
# 38    Call of Duty: Modern Warfare 3      PS3  2011.0  Shooter
# 41           Call of Duty: Black Ops      PS3  2010.0  Shooter
# 44                            Halo 3     X360  2007.0  Shooter
#
#                    Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# Rank
# 10                  Nintendo     26.93      0.63      0.28         0.47
# 30                Activision      9.03      4.28      0.13         1.32
# ...

# %%
# DESCRIBE SUR LES VARIABLES CONTINUES

df.describe()
# Out:
#                Year      NA_Sales      EU_Sales      JP_Sales   Other_Sales  \
# count  16327.000000  16598.000000  16598.000000  16598.000000  16598.000000
# mean    2006.406443      0.264667      0.146652      0.077782      0.048063
# std        5.828981      0.816683      0.505351      0.309291      0.188588
# min     1980.000000      0.000000      0.000000      0.000000      0.000000
# 25%     2003.000000      0.000000      0.000000      0.000000      0.000000
# 50%     2007.000000      0.080000      0.020000      0.000000      0.010000
# 75%     2010.000000      0.240000      0.110000      0.040000      0.040000
# max     2020.000000     41.490000     29.020000     10.220000     10.570000
#
#        Global_Sales
# count  16598.000000
# mean       0.537441
# std        1.555028
# min        0.010000
# 25%        0.060000
# 50%        0.170000
# 75%        0.470000
# max       82.740000

# %%
df.isna().sum()
# Out:
# Name              0
# Platform          0
# Year            271
# Genre             0
# Publisher        58
# NA_Sales          0
# EU_Sales          0
# JP_Sales          0
# Other_Sales       0
# Global_Sales      0
# dtype: int64

# %%
df.duplicated()
# Out:
# Rank
# 1        False
# 2        False
# 3        False
# 4        False
# 5        False
#          ...
# 16596    False
# 16597    False
# 16598    False
# 16599    False
# 16600    False
# Length: 16598, dtype: bool

# %%
df.head(20)
#idée graphiques:
# 1/ répartition des jeux par catégorie
# 2/ Nb de jeux sortis par an (et par plateforme ?)
# 3/ Nb de jeux sortits par an et par Publisher
# 4/ Répartition des Sales par catégorie / Publisher / plateforme
# 5/ Répartition des Sales par Région
# Out:
#                                               Name Platform    Year  \
# Rank
# 1                                       Wii Sports      Wii  2006.0
# 2                                Super Mario Bros.      NES  1985.0
# 3                                   Mario Kart Wii      Wii  2008.0
# 4                                Wii Sports Resort      Wii  2009.0
# 5                         Pokemon Red/Pokemon Blue       GB  1996.0
# 6                                           Tetris       GB  1989.0
# 7                            New Super Mario Bros.       DS  2006.0
# 8                                         Wii Play      Wii  2006.0
# 9                        New Super Mario Bros. Wii      Wii  2009.0
# 10                                       Duck Hunt      NES  1984.0
# 11                                      Nintendogs       DS  2005.0
# 12                                   Mario Kart DS       DS  2005.0
# 13                     Pokemon Gold/Pokemon Silver       GB  1999.0
# ...

# %%
# test d'un doublon de jeu
df[df['Name']=='Grand Theft Auto V'].head()
# Out:
#                     Name Platform    Year   Genre             Publisher  \
# Rank
# 17    Grand Theft Auto V      PS3  2013.0  Action  Take-Two Interactive
# 24    Grand Theft Auto V     X360  2013.0  Action  Take-Two Interactive
# 45    Grand Theft Auto V      PS4  2014.0  Action  Take-Two Interactive
# 198   Grand Theft Auto V     XOne  2014.0  Action  Take-Two Interactive
# 1898  Grand Theft Auto V       PC  2015.0  Action  Take-Two Interactive
#
#       NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# Rank
# 17        7.01      9.27      0.97         4.14         21.40
# 24        9.63      5.31      0.06         1.38         16.38
# 45        3.80      5.81      0.36         2.02         11.98
# 198       2.66      2.01      0.00         0.41          5.08
# 1898      0.36      0.64      0.00         0.08          1.08

# %%
# 1/ répartition des jeux par catégorie
ax = sns.countplot(x='Genre',data=df,order=df['Genre'].value_counts().index)
plt.xticks(rotation=45);
plt.ylabel('Nb de jeux vendus')
plt.title('Distribution du nombre de jeu par catégorie');

total = len(df)
# code honteusement pompé de l'internet !
# Mais ça a le mérite de fonctionner et de rajouter les % au dessus de chaque barre
for p in ax.patches:
    percentage = f'{100 * p.get_height() / total:.1f}%\n'
    x = p.get_x() + p.get_width() / 2
    y = p.get_height()
    ax.annotate(percentage, (x, y), ha='center', va='center')

# %%
# 1 - BIS / répartition des ventes par catégorie
df_SC=df.groupby(['Genre']).agg({'Global_Sales':sum}).sort_values(by='Global_Sales',ascending=False)

ax2 = sns.barplot(x=df_SC.index,y='Global_Sales',data=df_SC)
plt.xticks(rotation=45);
plt.ylabel('Total des Ventes en M d unites vendues')
plt.title('Distribution des ventes en Millions d unités vendues par catégorie');

total2 = df_SC.Global_Sales.sum()
# code honteusement pompé de l'internet !
# Mais ça a le mérite de fonctionner et de rajouter les % au dessus de chaque barre
for t in ax2.patches:
    percentage = f'{100 * t.get_height() / total2:.1f}%\n'
    x = t.get_x() + t.get_width() / 2
    y = t.get_height()
    ax2.annotate(percentage, (x, y), ha='center', va='center')

# On observe que la répartition reste globalement la même, il n'y a pas d'écart flagrant

# %%
df_SC
# Out:
#               Global_Sales
# Genre
# Action             1751.18
# Sports             1330.93
# Shooter            1037.37
# Role-Playing        927.37
# Platform            831.37
# Misc                809.96
# Racing              732.04
# Fighting            448.91
# Simulation          392.20
# Puzzle              244.95
# Adventure           239.04
# Strategy            175.12

# %%
#idem avec les années
df['Year']=pd.to_datetime(df['Year'], format='%Y')
df2=df.groupby(['Year','Genre']).agg({'NA_Sales':sum, 'EU_Sales':sum, 'JP_Sales':sum, 'Other_Sales':sum,'Global_Sales':sum})

# %%
cor = df.corr()

fig, ax = plt.subplots(figsize=(12,12))
sns.heatmap(cor, annot=True, ax=ax, cmap='coolwarm');
# Heatmap inutile !! :D

# %%
# 2/ Répartition des ventes  par an (et par plateforme ?)

# changement de 'YEAR' au format date
df['Year']=pd.to_datetime(df['Year'], format='%Y')
df_year=df.groupby(['Year']).agg({'NA_Sales':sum, 'EU_Sales':sum, 'JP_Sales':sum, 'Other_Sales':sum,'Global_Sales':sum})

# on teste une boucle for sur des graphs :D
# liste des noms des colonnes : df_year.columns
plt.figure(figsize=(10,5))
for colonne in df_year.columns :
    plt.plot_date(x=df_year.index,y=df_year[colonne],xdate=True,linestyle='-',label=colonne);
plt.grid()
plt.title('Répartition des ventes par année et par Région')
plt.xlabel('Année de sortie')
plt.ylabel('Ventes en M dunites')
plt.legend();

#ça marche :D aahahah

# %%
# 2 BIS / Nb de jeux sortis par an (et par plateforme ?)

# changement de 'YEAR' au format date
#df['Year']=pd.to_datetime(df['Year'], format='%Y')
df2_year=df['Year'].value_counts().sort_index()

plt.figure(figsize=(10,5))
plt.plot_date(x=df2_year.index,y=df2_year.values,xdate=True,linestyle='-.');
plt.grid()
plt.title('Nombre de jeux sortis par an')
plt.xlabel('Année de sortie')
plt.ylabel('Nombre de jeux');

# Graph bizarre et incohérent après 2008 ??? 
# Le nombre de jeux sortis par an ne peut pas chuter comme cela
# on peut se poser 2 questions : 
    # 1/ les données que nous avons dans ce dataset sont elles fiables ?
    # 2/ d'où pourraient provenir ces données ?

# %%
plt.figure(figsize=(5,5))
df3=pd.read_csv(path, index_col=0)


#plt.bar(x=df2_year.index,height=df2_year.values,);

# %%
# 3/ TOP 10 Nb de jeux sortis  et ventes par an et par Publisher

df_top10=df.groupby(['Publisher']).agg({'Global_Sales' : sum}).sort_values(by='Global_Sales',ascending=False).nlargest(10,'Global_Sales')

plt.figure(figsize=(15,5))
ax = sns.barplot(x=df_top10.index,y=df_top10.Global_Sales)
plt.xticks(rotation=45,ha='right');
plt.ylabel('Ventes en M€')
plt.title('TOP 10 des ventes générées par Publisher');

total = len(df)
# code honteusement pompé de l'internet !
# Mais ça a le mérite de fonctionner et de rajouter les % au dessus de chaque barre
for p in ax.patches:
    percentage = f'{100 * p.get_height() / total:.1f}%\n'
    x = p.get_x() + p.get_width() / 2
    y = p.get_height()
    ax.annotate(percentage, (x, y), ha='center', va='center')

# %%
# 4/ Répartition des Sales par catégorie / Publisher / plateforme
plt.figure(figsize=(15,5))
ax = sns.countplot(x='Platform',data=df,order=df['Platform'].value_counts().index)
plt.xticks(rotation=45);
plt.ylabel('Nb de jeux sortis')
plt.title('Répartition du nombre de jeux sortis par Plateforme');

total = len(df)
# code honteusement pompé de l'internet !
# Mais ça a le mérite de fonctionner et de rajouter les % au dessus de chaque barre
for p in ax.patches:
    percentage = f'{100 * p.get_height() / total:.1f}%\n'
    x = p.get_x() + p.get_width() / 2
    y = p.get_height()
    ax.annotate(percentage, (x, y), ha='center', va='center')

# %%
# 5/ Répartition des Sales par Région et par an ?
plt.figure(figsize=(15,5))
valeurs=df[['NA_Sales','EU_Sales','JP_Sales','Other_Sales']].sum()
plt.title('Répartition des Sales par Région')
plt.pie(x=valeurs.values,labels=valeurs.index,autopct=lambda x : str(round(x,2))+'%');

# %%
# TOP 10 des jeux ayant généré le plus de vente (par catégorie ?)
df_name10=df.groupby(['Name']).agg({'Global_Sales' : sum}).sort_values(by='Global_Sales',ascending=False).head(10)
sns.barplot(y=df_name10.index,x=df_name10.Global_Sales)
plt.title('TOP 10 des jeux avec le plus de ventes')
plt.xlabel('Ventes en M d"unités')
plt.ylabel('Nom du jeu')
# Out:
# Text(0, 0.5, 'Nom du jeu')

# %%
df.Platform.unique()
# Out:
# array(['Wii', 'NES', 'GB', 'DS', 'X360', 'PS3', 'PS2', 'SNES', 'GBA',
#        '3DS', 'PS4', 'N64', 'PS', 'XB', 'PC', '2600', 'PSP', 'XOne', 'GC',
#        'WiiU', 'GEN', 'DC', 'PSV', 'SAT', 'SCD', 'WS', 'NG', 'TG16',
#        '3DO', 'GG', 'PCFX'], dtype=object)

# %%
# 6 / Nb de jeux sortis par an et par plateforme

# changement de 'YEAR' au format date
df['Year']=pd.to_datetime(df['Year'], format='%Y')

l_plat=['PC','X360','XB','Xone','PS','PS2','PS3','PS4']
df[df['Platform']=='DS']['Year'].value_counts().sort_index()

plt.figure(figsize=(20,8))
for i in l_plat :
    df_temp=df[df['Platform']==i]['Year'].value_counts().sort_index()
    plt.plot_date(x=df_temp.index,y=df_temp.values,xdate=True,linestyle='-',label=i);
plt.legend();

# date de sortie des consoles:
# PS: 1994/ PS2:2000 / PS3: 2006 / PS4: 2013
# XB: 2001 / X360:2005 / Xone: 2013

# %%
# 7/ Etude des jeux PC
df_PC=df[df['Platform']=='PC']

df_PC.groupby('Name').agg({'Global_Sales':sum}).sort_values(by='Global_Sales',ascending=False).head(20)
# vraiment pas cohérent avec la page Wikipédia...
# Out:
#                                         Global_Sales
# Name
# The Sims 3                                      8.11
# World of Warcraft                               6.28
# Diablo III                                      5.20
# Microsoft Flight Simulator                      5.12
# StarCraft II: Wings of Liberty                  4.83
# Warcraft II: Tides of Darkness                  4.21
# Half-Life                                       4.12
# World of Warcraft: The Burning Crusade          4.09
# The Elder Scrolls V: Skyrim                     3.88
# The Sims: Unleashed                             3.76
# Doom II: Hell on Earth                          3.61
# The Sims: Vacation                              3.07
# The Sims: Livin Large                           2.99
# The Sims 4                                      2.97
# Star Wars: The Old Republic                     2.97
# Command & Conquer: Red Alert                    2.85
# Myst                                            2.81
# ...

# %%
# On observe des incohérences de ventes : Skyrim = 30 M d'unités vendues, à 50 € le jeu...

# %%
# classement jeu plus vendus sur Atari 2600 vs wikipédia
df_A2600=df[df['Platform']=='2600']
df_A2600.groupby('Name').agg({'Global_Sales':sum}).sort_values(by='Global_Sales',ascending=False).head(10)

# Global Sales = En M d'UNITES VENDUES
# cohérent sur quelques lignes mais pas fou...
# Out:
#                              Global_Sales
# Name
# Pac-Man                              7.81
# Pitfall!                             4.50
# Asteroids                            4.31
# Missile Command                      2.76
# Space Invaders                       2.53
# Frogger                              2.20
# Demon Attack                         2.13
# E.T.: The Extra Terrestrial          1.97
# Ms. Pac-Man                          1.65
# Dig Dug                              1.64

# %%
df.Platform.unique()
# Out:
# array(['Wii', 'NES', 'GB', 'DS', 'X360', 'PS3', 'PS2', 'SNES', 'GBA',
#        '3DS', 'PS4', 'N64', 'PS', 'XB', 'PC', '2600', 'PSP', 'XOne', 'GC',
#        'WiiU', 'GEN', 'DC', 'PSV', 'SAT', 'SCD', 'WS', 'NG', 'TG16',
#        '3DO', 'GG', 'PCFX'], dtype=object)

# %%
df.Platform.value_counts()
# Out:
# DS      2163
# PS2     2161
# PS3     1329
# Wii     1325
# X360    1265
# PSP     1213
# PS      1196
# PC       960
# XB       824
# GBA      822
# GC       556
# 3DS      509
# PSV      413
# PS4      336
# N64      319
# SNES     239
# XOne     213
# SAT      173
# WiiU     143
# 2600     133
# NES       98
# GB        98
# DC        52
# GEN       27
# NG        12
# SCD        6
# WS         6
# 3DO        3
# TG16       2
# GG         1
# PCFX       1
# Name: Platform, dtype: int64

# %% [markdown]
# On garde en consoles:
# 'DS','PS2','PS3','Wii','X360','PSP','PS','XB','GBA','3DS','PSV','PS4','XOne'
#
# Conservation uniquement des consoles de salons: (non portables) ?
# 'PS2','PS3','X360','PS','XB','PS4','XOne'

# %%
all_consoles = ['DS','PS2','PS3','Wii','X360','PSP','PS','XB','GBA','3DS','PSV','PS4','XOne']
salon_consoles = ['PS2','PS3','X360','PS','XB','PS4','XOne']

# %%
df_all_con=df[df.Platform.isin(all_consoles)]
df_all_con.Year = df_all_con.Year.dt.year
df_all_con = df_all_con[(df_all_con['Year']>=1994) & (df_all_con['Year']<=2008)]
df_all_con.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7686 entries, 1 to 16600
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Name          7686 non-null   object
#  1   Platform      7686 non-null   object
#  2   Year          7686 non-null   float64
#  3   Genre         7686 non-null   object
#  4   Publisher     7661 non-null   object
#  5   NA_Sales      7686 non-null   float64
#  6   EU_Sales      7686 non-null   float64
#  7   JP_Sales      7686 non-null   float64
#  8   Other_Sales   7686 non-null   float64
#  9   Global_Sales  7686 non-null   float64
# dtypes: float64(6), object(4)
# memory usage: 660.5+ KB
# C:\Users\Guillaume\AppData\Local\Temp\ipykernel_11792\664644514.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
df_consalon = df[df.Platform.isin(salon_consoles)]
df_consalon.Year = df_consalon.Year.dt.year
df_consalon = df_consalon[(df_consalon['Year']>=1994) & (df_consalon['Year']<=2008)]
df_consalon.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4614 entries, 18 to 16598
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Name          4614 non-null   object
#  1   Platform      4614 non-null   object
#  2   Year          4614 non-null   float64
#  3   Genre         4614 non-null   object
#  4   Publisher     4614 non-null   object
#  5   NA_Sales      4614 non-null   float64
#  6   EU_Sales      4614 non-null   float64
#  7   JP_Sales      4614 non-null   float64
#  8   Other_Sales   4614 non-null   float64
#  9   Global_Sales  4614 non-null   float64
# dtypes: float64(6), object(4)
# memory usage: 396.5+ KB
# C:\Users\Guillaume\AppData\Local\Temp\ipykernel_11792\1687516252.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...
